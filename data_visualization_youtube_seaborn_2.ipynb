# %% [markdown]
# #  class 6 violin plot

# %%
import seaborn as sns

# %%
import pandas as pd  # to import data sheet

# %%
sales = pd.read_excel('sales.xls') # read excel sales file

# %%
sales.head(2)
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity     Sales  \
# 0       1         3 2010-10-13            Low               6    261.54
# 1      49       293 2012-10-01           High              49  10123.02
#
#    Discount       Ship Mode  Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air -213.25       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck  457.81      208.16  ...        Barry French
#
#   Province   Region Customer Segment Product Category    Product Sub-Category  \
# 0  Nunavut  Nunavut   Small Business  Office Supplies  Storage & Organization
# 1  Nunavut  Nunavut         Consumer  Office Supplies              Appliances
#
#                                         Product Name Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Jumbo Drum
#
#   Product Base Margin  Ship Date
# 0                0.80 2010-10-20
# ...

# %%
sns.catplot(x='Product Category',y='Shipping Cost',data=sales,kind='violin') #using violin plot better to visualizing data

# %%
sns.catplot(x='Product Category',y='Shipping Cost',hue='Ship Mode',data=sales,kind='violin') #using diffrent ship mode in chart

# %%
sns.catplot(x='Product Category',y='Shipping Cost',hue='Ship Mode',inner='stick',data=sales,kind='violin') 
# using inner stick beter to visualizing a data

# %% [markdown]
# # class 7 Bar Chart

# %%
 sales.head(2)
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity     Sales  \
# 0       1         3 2010-10-13            Low               6    261.54
# 1      49       293 2012-10-01           High              49  10123.02
#
#    Discount       Ship Mode  Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air -213.25       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck  457.81      208.16  ...        Barry French
#
#   Province   Region Customer Segment Product Category    Product Sub-Category  \
# 0  Nunavut  Nunavut   Small Business  Office Supplies  Storage & Organization
# 1  Nunavut  Nunavut         Consumer  Office Supplies              Appliances
#
#                                         Product Name Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Jumbo Drum
#
#   Product Base Margin  Ship Date
# 0                0.80 2010-10-20
# ...

# %%
sns.catplot(x='Product Category',y='Sales',data=sales,kind="bar") # using Bar chart

# %%
sales.columns  # check what veriable there in columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
#        'Shipping Cost', 'Customer Name', 'Province', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin',
#        'Ship Date'],
#       dtype='object')

# %%
sns.catplot(x='Product Category',y='Sales',hue='Ship Mode',data=sales,kind="bar")  
# using hue for unerstand 3 diffrent ship mode

# %%
sns.catplot(x='Product Category',y='Sales',hue='Ship Mode',col='Customer Segment',data=sales,kind="bar")  
# using colum as col for deffrent typr of customer segment and all so use row

# %%
sns.catplot(x='Sales',y='Product Category',data=sales,kind="bar")  # for horizental view of bar chart

# %% [markdown]
# #  Class 8 Point plot

# %%
sales.head(2)
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity     Sales  \
# 0       1         3 2010-10-13            Low               6    261.54
# 1      49       293 2012-10-01           High              49  10123.02
#
#    Discount       Ship Mode  Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air -213.25       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck  457.81      208.16  ...        Barry French
#
#   Province   Region Customer Segment Product Category    Product Sub-Category  \
# 0  Nunavut  Nunavut   Small Business  Office Supplies  Storage & Organization
# 1  Nunavut  Nunavut         Consumer  Office Supplies              Appliances
#
#                                         Product Name Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Jumbo Drum
#
#   Product Base Margin  Ship Date
# 0                0.80 2010-10-20
# ...

# %%
sns.catplot(x='Product Category',y='Sales',data=sales,kind='point') # using point plot

# %%
sns.catplot(x='Product Category',y='Sales',hue='Ship Mode',data=sales,kind='point')

# %%
sns.catplot(x='Product Category',y='Sales',hue='Region',data=sales,kind='point')

# %%
sns.catplot(x='Product Category',y='Sales',hue='Ship Mode',col='Customer Segment',data=sales,kind='point')
