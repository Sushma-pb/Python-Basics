# %% [markdown]
# # 1)Basic Terminology

# %%
#what is EDA?
#Data-points/vector /Observation
#data-set
#feature/variable/input-variable/independent-variable/dependent-variable

# %% [markdown]
# # IRIS FLOWER DATA-SET

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
iris=pd.read_csv("Iris.csv")  #load iris.csv into a pandas dataframe
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %%
print(iris.shape)
# Out:
# (150, 6)

# %%
print(iris.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris["Species"].value_counts()
# Out:
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %% [markdown]
# # 2-D Scatter Plot

# %%
iris.plot (kind='Scatter',x='SepalLengthCm',y='SepalWidthCm');
plt.show()

# %%
sns.set_style("whitegrid");      #sns corrensponds to seaborn
sns.FacetGrid(iris, hue="Species",size=4)\
   .map(plt.scatter,"SepalLengthCm", "SepalWidthCm")\
   .add_legend();
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # 3D-Scatter Plot
#
# a)PAIR PLOT

# %%
plt.close();
sns.set_style("whitegrid");
sns.pairplot(iris,hue='Species',size=3,diag_kind="kde");
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
#NOTE:THE diagnol elements are PDFs for each feature

# %%
iris.plot (kind='Scatter',x='SepalLengthCm',y='SepalWidthCm',z='PetalWidthCm')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-915e11e0ebab> in <module>
# ----> 1 iris.plot (kind='Scatter',x='SepalLengthCm',y='SepalWidthCm',z='PetalWidthCm')
#       2 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2940                           fontsize=fontsize, colormap=colormap, table=table,
#    2941                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2942                           sort_columns=sort_columns, **kwds)
#    2943     __call__.__doc__ = plot_frame.__doc__
#    2944
#
# ...
