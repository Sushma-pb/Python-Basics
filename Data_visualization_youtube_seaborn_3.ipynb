# %% [markdown]
# #  Class 9 Distribution Plot

# %%
import pandas as pd # to import data sheet

# %%
import seaborn as sns # import plot

# %%
import numpy as np # import numpy  package

# %%
sales=pd.read_excel('sales.xls') #read sales file

# %%
sales.head(2)
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity     Sales  \
# 0       1         3 2010-10-13            Low               6    261.54
# 1      49       293 2012-10-01           High              49  10123.02
#
#    Discount       Ship Mode  Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air -213.25       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck  457.81      208.16  ...        Barry French
#
#   Province   Region Customer Segment Product Category    Product Sub-Category  \
# 0  Nunavut  Nunavut   Small Business  Office Supplies  Storage & Organization
# 1  Nunavut  Nunavut         Consumer  Office Supplies              Appliances
#
#                                         Product Name Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Jumbo Drum
#
#   Product Base Margin  Ship Date
# 0                0.80 2010-10-20
# ...

# %%
sns.distplot(sales.Sales) #  sales to use in  distribution plot using distplot

# %%
sns.distplot(sales.Profit) # profit to use in distribution plot

# %%
sns.distplot(sales.Profit, hist=False) # only showing histogram

# %%
sns.distplot(sales.Profit, hist=False, rug=True) # using rug to check how mony data point we having in x axes

# %%
sns.distplot(sales.Profit,kde=False,rug=True,bins=100)

# %%
sns.distplot(sales.Profit[(sales.Region == "West" )& (sales.Profit>0)], hist=False, rug=True)
# check it in particuler region of profit gretar then 0

# %%
sns.distplot(sales.Profit)

# %%
sns.kdeplot(sales.Profit,bw=1000)# check bandwidth in kdeplot

# %%
from scipy import stats  # import scipy library for gamma,beta,lot of distribution

# %%
a= np.random.gamma(3,size=200)

# %%
sns.distplot(a)

# %%
sns.distplot(a,fit=stats.gamma) # fit parameter help to fit distrubution

# %%
b= np.random.beta(7,7,size=200) # using beta parameter to distribution data

# %%
sns.distplot(b,kde=False,fit=stats.beta)

# %% [markdown]
# # Class 10 Jiont Plot and Pair Plot

# %%
sales.head(2)
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity     Sales  \
# 0       1         3 2010-10-13            Low               6    261.54
# 1      49       293 2012-10-01           High              49  10123.02
#
#    Discount       Ship Mode  Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air -213.25       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck  457.81      208.16  ...        Barry French
#
#   Province   Region Customer Segment Product Category    Product Sub-Category  \
# 0  Nunavut  Nunavut   Small Business  Office Supplies  Storage & Organization
# 1  Nunavut  Nunavut         Consumer  Office Supplies              Appliances
#
#                                         Product Name Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Jumbo Drum
#
#   Product Base Margin  Ship Date
# 0                0.80 2010-10-20
# ...

# %%
sns.jointplot('Sales','Profit',data=sales) #using jointplot for 2 data

# %%
sns.jointplot('Sales','Discount',data=sales)

# %%
sns.jointplot('Sales','Product Base Margin',data=sales)

# %%
sns.jointplot('Sales','Product Base Margin',data=sales,kind='hex')
# dark color of point chart  show in constration of value ofproduct base margin using hex

# %%
sns.jointplot('Discount','Product Base Margin',data=sales,kind='hex')

# %%
sns.jointplot('Discount','Product Base Margin',data=sales,kind='kde') #using kde  for better picture of data

# %%
sns.pairplot(sales) # using pairplot to see all data in one

# %%
sns.pairplot(sales,hue='Ship Mode') # using hue to more colorful to see data
