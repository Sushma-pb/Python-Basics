# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
ml_students_age =np.random.randint(18,45,(100))
py_students_age=np.random.randint(15,40,(100))

# %%
print(ml_students_age)
print(py_students_age)
# Out:
# [30 43 37 34 30 20 42 34 24 31 22 44 35 19 35 42 39 43 27 32 31 27 27 24
#  38 31 32 23 37 36 32 21 22 27 25 30 41 26 20 21 37 25 34 30 35 18 29 39
#  43 36 35 41 30 32 29 41 26 25 37 43 40 29 30 39 40 34 44 32 27 22 43 40
#  31 29 39 22 28 28 41 36 20 19 43 36 42 18 42 37 32 28 22 38 34 43 36 29
#  19 26 39 34]
# [22 15 38 15 24 31 35 20 20 27 33 29 16 30 33 31 36 34 20 24 26 29 32 31
#  19 37 36 31 31 35 34 36 20 22 39 15 26 18 32 32 21 27 27 29 32 28 28 20
#  35 32 29 15 26 32 25 27 21 30 21 33 38 16 30 28 34 16 19 18 29 37 32 23
#  26 31 29 24 26 33 28 26 39 21 39 15 33 37 23 22 35 25 29 33 16 22 35 20
#  31 28 39 19]

# %%
bins=[5,10,15,20,25,30,35,40] #bins used to devide classes
plt.hist(ml_students_age,bins,rwidth=0.8,histtype='bar',orientation='horizontal',color='g',label="ML student")  #histogram function

plt.title("ML students age histograms",fontsize=16)
plt.xlabel("students age catogary")
plt.ylabel("no.students age")
plt.legend()
plt.grid(color="g")
plt.show()

# %%
#bins= devide ur classes by default bins has been taken meaning the classes has been created in th x axis
#width=our bars have occupied 100 % width lets change the p% of it
#listtype= let us give step as value

# %%
from matplotlib import style
style.use("ggplot")
plt.figure(figsize=(16,9)) # increse the size of the bar

bins=[5,10,15,20,25,30,35,40] #bins used to devide classes
plt.hist(ml_students_age,bins,rwidth=0.8,histtype='bar',orientation='horizontal',color='g',label="ML student")  #histogram function
plt.hist(py_students_age,bins,rwidth=0.8,histtype='bar',orientation='horizontal',color='r',label="ML student")
plt.title("ML students age histograms",fontsize=16)
plt.xlabel("students age catogary")
plt.ylabel("no.students age")
plt.legend()
plt.grid(color="g")
plt.show()

# %%
from matplotlib import style
style.use("ggplot")
plt.figure(figsize=(10,8)) # increse the size of the bar

bins=[5,10,15,20,25,30,35,40] #bins used to devide classes
plt.hist([ml_students_age,py_students_age],bins,rwidth=0.8,histtype='bar',orientation='vertical',color=['g','r'],label=["ML student","py student"])  #histogram function
#plt.hist(py_students_age,bins,rwidth=0.8,histtype='bar',orientation='horizontal',color='r',label="ML student")
plt.title("ML students age histograms",fontsize=16)
plt.xlabel("students age catogary")
plt.ylabel("no.students age")
plt.legend()
plt.grid(color="g")
plt.show()
